# %% [markdown]
# # Heart Disease Data Prediction
#
# The term “heart disease” refers to several types of heart conditions. the most common type of heart disease is coronary artery disease (CAD), which can lead to heart attack. You can greatly reduce your risk for heart disease through lifestyle changes and, in some cases, medicine. Here we will perform an analysis to find the main and related causes of heart disease.

# %%
#Importing Necessory Libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from sklearn.metrics import accuracy_score
# Out:
# 2022-12-07 09:44:20.113233: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Dataset Loading & Understanding

# %%
df = pd.read_csv('/Users/abutalha/Documents/Data Analyst/AI Quest/Data Science/Heart Disease.csv')
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# # Basic Data Analysis
#
# Here we will perform some visualization to understand the dataset more.

# %%
df.AgeCategory.value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
df.Race.value_counts()
# Out:
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: Race, dtype: int64

# %%
df_raceVal = df.Race.value_counts().values
df_raceName = df.Race.value_counts().index

# %%
plt.pie(df_raceVal, labels=df_raceName,  radius=3, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad97b55f70>,
#   <matplotlib.patches.Wedge at 0x7fad97b796d0>,
#   <matplotlib.patches.Wedge at 0x7fad97b79df0>,
#   <matplotlib.patches.Wedge at 0x7fad97b86550>,
#   <matplotlib.patches.Wedge at 0x7fad97b86c70>,
#   <matplotlib.patches.Wedge at 0x7fad97b933d0>],
#  [Text(-2.453155004824234, 2.2072676598695082, 'White'),
#   Text(1.2088434421861607, -3.0706184283110654, 'Hispanic'),
#   Text(2.5223229542135175, -2.1278832004242143, 'Black'),
#   Text(3.0789692284005383, -1.1874125191198706, 'Other'),
#   Text(3.2458153379582257, -0.5955525097547071, 'Asian'),
#   Text(3.2956918830554907, -0.16856752938260333, 'American Indian/Alaskan Native')],
#  [Text(-1.3380845480859456, 1.2039641781106407, '76.68%'),
#   Text(0.6593691502833602, -1.6748827790787626, '8.58%'),
#   Text(1.3758125204801002, -1.160663563867753, '7.17%'),
#   Text(1.6794377609457478, -0.6476795558835657, '3.42%'),
#   Text(1.7704447297953956, -0.32484682350256744, '2.52%'),
#   Text(1.7976501180302673, -0.09194592511778361, '1.63%')])

# %%
df_ageVal = df.AgeCategory.value_counts().values
df_ageName = df.AgeCategory.value_counts().index

# %%
plt.pie(df_ageVal, labels=df_ageName,  radius=3, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fad97d4afa0>,
#   <matplotlib.patches.Wedge at 0x7fad97d59730>,
#   <matplotlib.patches.Wedge at 0x7fad97d59e80>,
#   <matplotlib.patches.Wedge at 0x7fad97d645e0>,
#   <matplotlib.patches.Wedge at 0x7fad97d64d00>,
#   <matplotlib.patches.Wedge at 0x7fad97bc6460>,
#   <matplotlib.patches.Wedge at 0x7fad97bc6b80>,
#   <matplotlib.patches.Wedge at 0x7fad97bd32e0>,
#   <matplotlib.patches.Wedge at 0x7fad97bd3a00>,
#   <matplotlib.patches.Wedge at 0x7fad97be1160>,
#   <matplotlib.patches.Wedge at 0x7fad97d4af70>,
#   <matplotlib.patches.Wedge at 0x7fad97be1f70>,
#   <matplotlib.patches.Wedge at 0x7fad97bf06d0>],
#  [Text(3.1160203022980113, 1.0864701908780614, '65-69'),
#   Text(1.7776997007697084, 2.7802488690553027, '60-64'),
#   Text(-0.22162394718718986, 3.2925495935571223, '70-74'),
#   Text(-2.0355438488796715, 2.597414337237734, '55-59'),
#   Text(-3.0832996451039563, 1.1761221443803436, '50-54'),
#   Text(-3.2753883506557293, -0.4022824286353362, '80 or older'),
#   Text(-2.7719320906125273, -1.7906402444467915, '45-49'),
#   Text(-1.7867307032491695, -2.7744537109252208, '75-79'),
#   Text(-0.506777782066426, -3.2608551454494012, '18-24'),
#   Text(0.8455172374065498, -3.189843350581404, '40-44'),
#   Text(2.0423751575420956, -2.5920462410718876, '35-39'),
#   Text(2.868139765485506, -1.6321073143763396, '30-34'),
#   Text(3.25432994640055, -0.5471166237289765, '25-29')],
#  [Text(1.699647437617097, 0.5926201041153061, '10.68%'),
#   Text(0.9696543822380226, 1.516499383121074, '10.53%'),
#   Text(-0.12088578937483081, 1.7959361419402482, '9.71%'),
#   Text(-1.110296644843457, 1.4167714566751273, '9.31%'),
#   Text(-1.6817998064203397, 0.6415211696620055, '7.94%'),
#   Text(-1.7865754639940339, -0.2194267792556379, '7.55%'),
#   Text(-1.5119629585159238, -0.9767128606073406, '6.81%'),
#   Text(-0.9745803835904558, -1.513338387777393, '6.72%'),
#   Text(-0.276424244763505, -1.7786482611542185, '6.59%'),
#   Text(0.4611912204035725, -1.7399145548625838, '6.57%'),
#   Text(1.1140228132047791, -1.4138434042210293, '6.43%'),
#   Text(1.564439872083003, -0.8902403532961851, '5.86%'),
#   Text(1.775089061673027, -0.29842724930671444, '5.30%')])

# %%
df.Sex.value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %%
sns.countplot(x='Sex', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df[['Stroke', 'HeartDisease']].groupby(['Stroke', 'HeartDisease']).size().reset_index()
# Out:
#   Stroke HeartDisease       0
# 0     No           No  284742
# 1     No          Yes   22984
# 2    Yes           No    7680
# 3    Yes          Yes    4389

# %%
sns.countplot(x='Diabetic', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Diabetic', ylabel='count'>

# %%
sleepTime_count = df[['SleepTime', 'HeartDisease']].groupby(['SleepTime', 'HeartDisease']).size().reset_index().rename(columns={0:'SleepTime Count'})
sleepTime_count.head(10)
# Out:
#    SleepTime HeartDisease  SleepTime Count
# 0        1.0           No              491
# 1        1.0          Yes               60
# 2        2.0           No              660
# 3        2.0          Yes              128
# 4        3.0           No             1645
# 5        3.0          Yes              347
# 6        4.0           No             6570
# 7        4.0          Yes             1180
# 8        5.0           No            17154
# 9        5.0          Yes             2030

# %%
sleepTimeCount = sleepTime_count.sort_values(['SleepTime Count'], ascending=[False])
sleepTimeCount_top10 = sleepTimeCount.head(10)

# %%
sleepTimeCount_top10
# Out:
#     SleepTime HeartDisease  SleepTime Count
# 12        7.0           No            91426
# 14        8.0           No            89244
# 10        6.0           No            61294
# 8         5.0           No            17154
# 16        9.0           No            14345
# 15        8.0          Yes             8358
# 18       10.0           No             6631
# 6         4.0           No             6570
# 13        7.0          Yes             6325
# 11        6.0          Yes             5427

# %%
sns.barplot(x='SleepTime Count', y='SleepTime', data=sleepTimeCount_top10)
# Out:
# <AxesSubplot:xlabel='SleepTime Count', ylabel='SleepTime'>

# %%
sns.countplot(x='HeartDisease', data=sleepTimeCount_top10, hue='SleepTime Count')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %% [markdown]
# # Label Encoding
#
# Let's encode the categorical variable for deeper understanding.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.columns:
    if df[col].dtype == np.number:
        continue 
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2          30.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1          4        5.0       1              0           1
# 1                 1          4        7.0       0              0           0
# 2                 1          1        8.0       1              0           0
# 3                 0          2        6.0       0              0           1
# 4                 1          4        8.0       0              0           0

# %% [markdown]
# # Exploratory Data Analysis
#
# We will perform EDA & Pandas Profiling Library to investigate the dataset

# %%
df.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  319795.000000  319795.000000  319795.000000    319795.000000
# mean        0.085595      28.325399       0.412477         0.068097
# std         0.279766       6.356100       0.492281         0.251912
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.340000       0.000000         0.000000
# 75%         0.000000      31.420000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#               Stroke  PhysicalHealth   MentalHealth    DiffWalking  \
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean        0.037740         3.37171       3.898366       0.138870
# std         0.190567         7.95085       7.955235       0.345812
# min         0.000000         0.00000       0.000000       0.000000
# 25%         0.000000         0.00000       0.000000       0.000000
# 50%         0.000000         0.00000       0.000000       0.000000
# 75%         0.000000         2.00000       3.000000       0.000000
# max         1.000000        30.00000      30.000000       1.000000
#
#                  Sex    AgeCategory           Race       Diabetic  \
# count  319795.000000  319795.000000  319795.000000  319795.000000
# mean        0.475273       6.514536       4.396742       0.300386
# std         0.499389       3.564759       1.212208       0.716480
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       4.000000       5.000000       0.000000
# 50%         0.000000       7.000000       5.000000       0.000000
# 75%         1.000000       9.000000       5.000000       0.000000
# max         1.000000      12.000000       5.000000       3.000000
#
#        PhysicalActivity      GenHealth      SleepTime         Asthma  \
# count     319795.000000  319795.000000  319795.000000  319795.000000
# mean           0.775362       2.220904       7.097075       0.134061
# std            0.417344       1.534647       1.436007       0.340718
# min            0.000000       0.000000       1.000000       0.000000
# 25%            1.000000       1.000000       6.000000       0.000000
# 50%            1.000000       2.000000       7.000000       0.000000
# 75%            1.000000       4.000000       8.000000       0.000000
# max            1.000000       4.000000      24.000000       1.000000
#
#        KidneyDisease     SkinCancer
# count  319795.000000  319795.000000
# mean        0.036833       0.093244
# std         0.188352       0.290775
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000

# %%
df.corr()
# Out:
#                   HeartDisease       BMI   Smoking  AlcoholDrinking    Stroke  \
# HeartDisease          1.000000  0.051803  0.107764        -0.032080  0.196835
# BMI                   0.051803  1.000000  0.023118        -0.038816  0.019733
# Smoking               0.107764  0.023118  1.000000         0.111768  0.061226
# AlcoholDrinking      -0.032080 -0.038816  0.111768         1.000000 -0.019858
# Stroke                0.196835  0.019733  0.061226        -0.019858  1.000000
# PhysicalHealth        0.170721  0.109788  0.115352        -0.017254  0.137014
# MentalHealth          0.028591  0.064131  0.085157         0.051282  0.046467
# DiffWalking           0.201258  0.181678  0.120074        -0.035328  0.174143
# Sex                   0.070040  0.026940  0.085052         0.004200 -0.003091
# AgeCategory           0.233432 -0.004744  0.128331        -0.059528  0.137822
# Race                  0.034854 -0.037424  0.065499         0.036702 -0.003956
# Diabetic              0.168553  0.202472  0.053847        -0.057372  0.101518
# PhysicalActivity     -0.100030 -0.150616 -0.097174         0.017487 -0.079455
# GenHealth            -0.011062  0.035932  0.020625         0.001629 -0.009335
# SleepTime             0.008327 -0.051822 -0.030336        -0.005065  0.011900
# DiffWalking       -0.043552  -0.022216  0.103222       0.153064    0.064840
# Sex               -0.010283  -0.015704 -0.069191      -0.009084    0.013434
# AgeCategory        0.044427   0.104953 -0.058108       0.123190    0.263537
# Race               0.050344   0.035889 -0.017975       0.003709    0.134780
# Diabetic          -0.010854   0.000449  0.049827       0.142917    0.032523
# PhysicalActivity   0.024418   0.003849 -0.041526      -0.081827   -0.001328
# GenHealth          1.000000  -0.004163  0.007280      -0.010580    0.018982
# SleepTime         -0.004163   1.000000 -0.048245       0.006238    0.041266
# Asthma             0.007280  -0.048245  1.000000       0.039707   -0.000396
# KidneyDisease     -0.010580   0.006238  0.039707       1.000000    0.061816
# SkinCancer         0.018982   0.041266 -0.000396       0.061816    1.000000

# %%
plt.figure(figsize=(16,12))
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 10}, linewidths=2, linecolor='white', cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot( x="PhysicalHealth", y="MentalHealth", data=df, fit_reg=False, hue='HeartDisease', legend=True)

# %%
#Let's use Pandas Profiling to make a deeper understanding
import pandas_profiling.profile_report as ProfileReport
#df.profile_report()

# %% [markdown]
# # Feature Selection & Class Imbalancing
#
# Here we will seperate features in X and class in Y. We will also check class data imbalancing for avoiding bias.

# %%
#Checking the class vlaues for identifying data imbalancing
df.HeartDisease.value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %%
#It seems the data is imbalance. Let's dig more
imbalance = round(292422/(292422+27373),2)
print(f'{imbalance}% data is imbalance in Target Column')
# Out:
# 0.91% data is imbalance in Target Column

# %%
#There is a massive data imbalancing found in Class 
sns.countplot(df['HeartDisease'], color='green')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %%
no_HeartDisease = (292422/(292422+27373)) * 100
yes_HeartDisease = (27373/(292422+27373)) * 100

print(f'According to dataset {yes_HeartDisease}% people has Heart Disease')
print(f'According to dataset {no_HeartDisease}% people has no Heart Disease')
# Out:
# According to dataset 8.559545959130068% people has Heart Disease
# According to dataset 91.44045404086994% people has no Heart Disease

# %%
#Let's seperate the dataset first before sampling
X = df.drop('HeartDisease', axis=1)
y = df['HeartDisease']

# %%
X.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60        1                0       0             3.0          30.0
# 1  20.34        0                0       1             0.0           0.0
# 2  26.58        1                0       0            20.0          30.0
# 3  24.21        0                0       0             0.0           0.0
# 4  23.71        0                0       0            28.0           0.0
#
#    DiffWalking  Sex  AgeCategory  Race  Diabetic  PhysicalActivity  GenHealth  \
# 0            0    0            7     5         2                 1          4
# 1            0    0           12     5         0                 1          4
# 2            0    1            9     5         2                 1          1
# 3            0    0           11     5         0                 0          2
# 4            1    0            4     5         0                 1          4
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# 0        5.0       1              0           1
# 1        7.0       0              0           0
# 2        8.0       1              0           0
# 3        6.0       0              0           1
# 4        8.0       0              0           0

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: HeartDisease, dtype: int64

# %%
#Let's Over Sampling the dataset first

from imblearn.combine import SMOTETomek
sm = SMOTETomek()
X_OverSample, y_OverSample = sm.fit_resample(X,y)

# %%
#Now the Class value seems balanced
y_OverSample.value_counts()
# Out:
# 0    290190
# 1    290190
# Name: HeartDisease, dtype: int64

# %%
#Under Sampling the dataset for making the class value balanced
from imblearn.under_sampling import NearMiss
nm = NearMiss()
X_UnderSample, y_UnderSample = nm.fit_resample(X,y)

# %%
y_UnderSample.value_counts()
# Out:
# 0    27373
# 1    27373
# Name: HeartDisease, dtype: int64

# %%
print(f'The original Y values is: {y.shape}')
print(f'After Over Sampling the Y values is: {y_OverSample.shape}')
print(f'After Under Sampling the Y values is: {y_UnderSample.shape}')
# Out:
# The original Y values is: (319795,)
# After Over Sampling the Y values is: (580380,)
# After Under Sampling the Y values is: (54746,)

# %% [markdown]
# # Split the data in Train & Test
#
# Here we pick Under Sampling data and split them. We will also split them in folds for probable future usage.

# %%
#Importing Libraries 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score, cross_validate

# %%
#spliting the dataset
X_train, X_test, y_train, y_test = train_test_split(X_UnderSample, y_UnderSample, test_size = .30, random_state=1)

# %%
#spliting using kfold
kfold = KFold(n_splits=5, shuffle=True, random_state=2)

# %%
fold_number = 1
for train_fold, test_fold, in kfold.split(X_UnderSample, y_UnderSample):
    print(f'Fold:{fold_number}, Train set: {len(train_fold)}, Test set:{len(test_fold)}')
    fold_number += 1
# Out:
# Fold:1, Train set: 43796, Test set:10950
# Fold:2, Train set: 43797, Test set:10949
# Fold:3, Train set: 43797, Test set:10949
# Fold:4, Train set: 43797, Test set:10949
# Fold:5, Train set: 43797, Test set:10949

# %% [markdown]
# # Fit the Model with various Algorithms
#
# Let's fit the data and create a model with various algorithms

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier(n_neighbors=49)
dtc = DecisionTreeClassifier(min_samples_split=7, random_state=111)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=31, random_state=111)
abc = AdaBoostClassifier(n_estimators=62, random_state=111)
bc = BaggingClassifier(n_estimators=9, random_state=111)
etc = ExtraTreesClassifier(n_estimators=9, random_state=111)
xgb = XGBClassifier()
ann = tf.keras.models.Sequential()
# Out:
# 2022-12-07 09:51:38.165460: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
clfs = {'SVC' : svc,'KNC' : knc, 'DTC': dtc, 'LR': lrc, 'RFC': rfc, 'AdaBoost': abc, 'BgC': bc, 'ETC': etc, 'XgB': xgb,}

# %%
def train_classifier(clf, X_train, y_train):    
    clf.fit(X_train, y_train)

# %%
def predict_labels(clf, X_test):
    return (clf.predict(X_test))

# %%
pred_scores = []
for k,v in clfs.items():
    train_classifier(v, X_train, y_train)
    pred = predict_labels(v,X_test)
    pred_scores.append((k, [accuracy_score(y_test,pred)]))

# %%
model_scores = pd.DataFrame(pred_scores, columns=('Index','Score'))
model_scores
# Out:
#       Index                  Score
# 0       SVC  [0.49665124208475403]
# 1       KNC   [0.8441914271797369]
# 2       DTC   [0.8599001461276181]
# 3        LR   [0.8763395031660984]
# 4       RFC   [0.8544812469556746]
# 5  AdaBoost   [0.8920482221139795]
# 6       BgC    [0.860021919142718]
# 7       ETC   [0.8469922065270337]
# 8       XgB   [0.8987457379444715]

# %%
#Prepare the ANN for fitting the model
ann.add(tf.keras.layers.Dense(units=6,activation="relu"
# 1198/1198 [==============================] - 1s 844us/step - loss: 0.2770 - accuracy: 0.8853
# Epoch 85/100
# 1198/1198 [==============================] - 1s 846us/step - loss: 0.2766 - accuracy: 0.8865
# Epoch 86/100
# 1198/1198 [==============================] - 1s 844us/step - loss: 0.2770 - accuracy: 0.8865
# Epoch 87/100
# 1198/1198 [==============================] - 1s 845us/step - loss: 0.2768 - accuracy: 0.8863
# Epoch 88/100
# 1198/1198 [==============================] - 1s 847us/step - loss: 0.2770 - accuracy: 0.8866
# Epoch 89/100
# 1198/1198 [==============================] - 1s 829us/step - loss: 0.2768 - accuracy: 0.8868
# Epoch 90/100
# 1198/1198 [==============================] - 1s 828us/step - loss: 0.2771 - accuracy: 0.8859
# Epoch 91/100
# 1198/1198 [==============================] - 1s 839us/step - loss: 0.2770 - accuracy: 0.8863
# Epoch 92/100
# 1198/1198 [==============================] - 1s 837us/step - loss: 0.2762 - accuracy: 0.8864
# Epoch 93/100
# 1198/1198 [==============================] - 1s 866us/step - loss: 0.2765 - accuracy: 0.8865
# Epoch 94/100
# 1198/1198 [==============================] - 1s 831us/step - loss: 0.2766 - accuracy: 0.8871
# Epoch 95/100
# 1198/1198 [==============================] - 1s 833us/step - loss: 0.2767 - accuracy: 0.8862
# Epoch 96/100
# 1198/1198 [==============================] - 1s 832us/step - loss: 0.2761 - accuracy: 0.8861
# Epoch 97/100
# 1198/1198 [==============================] - 1s 834us/step - loss: 0.2763 - accuracy: 0.8863
# Epoch 98/100
# 1198/1198 [==============================] - 1s 946us/step - loss: 0.2765 - accuracy: 0.8870
# Epoch 99/100
# 1198/1198 [==============================] - 1s 839us/step - loss: 0.2760 - accuracy: 0.8858
# Epoch 100/100
# 1198/1198 [==============================] - 1s 848us/step - loss: 0.2756 - accuracy: 0.8864

# %%
#ANN Accuracy Score
ann_pred = ann.predict(X_test)
ann_score = accuracy_score(y_test,pred)
ann_score
# Out:
# 514/514 [==============================] - 0s 610us/step
# 0.8987457379444715

# %%
#Fit with Kfolds
kfold_score = cross_val_score(xgb, X_test, y_test, cv=kfold)
kfold_score
# Out:
# array([0.89041096, 0.89315068, 0.89497717, 0.895586  , 0.88824604])

# %%
#Let's fit he model with Another Algorithm
from sklearn.ensemble import VotingClassifier
eclf = VotingClassifier(estimators=[('BgC', bc), ('ETC', etc), ('RF', rfc), ('Ada', abc)], voting='soft')
eclf.fit(X_train,y_train)
vt_pred = eclf.predict(X_test)
vt_score = eclf.score(X_test,y_test)
vt_score
# Out:
# 0.8549074525085241

# %% [markdown]
# # Hyper Parameter Tuning
#
# After fitting the model with many algorithms we found XgBoost scored better. So now we will try to increase our score performing hyper parameter tuning of Xgb.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix

# %%
params = {
    'max_depth':range(3,10,2),
    'min_child_weight':range(1,6,2),
    'max_depth':[4,5,6,8,10],
    'gamma':[i/10.0 for i in range(0,5)],
    'subsample':[i/10.0 for i in range(6,10)],
    'colsample_bytree':[i/10.0 for i in range(6,10)],
    'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
}

print(params)
# Out:
# {'max_depth': [4, 5, 6, 8, 10], 'min_child_weight': range(1, 6, 2), 'gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 'subsample': [0.6, 0.7, 0.8, 0.9], 'colsample_bytree': [0.6, 0.7, 0.8, 0.9], 'reg_alpha': [1e-05, 0.01, 0.1, 1, 100]}

# %%
tuning_xgb_clf = XGBClassifier()
tuning_xgb_rcv = RandomizedSearchCV(tuning_xgb_clf, params, n_iter=200, cv=3)
tuning_xgb_rcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None, ...),
#                    n_iter=200,
#                    param_distributions={'colsample_bytree': [0.6, 0.7, 0.8,
#                                                              0.9],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'max_depth': [4, 5, 6, 8, 10],
#                                         'min_child_weight': range(1, 6, 2),
#                                         'reg_alpha': [1e-05, 0.01, 0.1, 1, 100],
#                                         'subsample': [0.6, 0.7, 0.8, 0.9]})

# %%
tuning_xgb_rcv.cv_results_
# Out:
# {'mean_fit_time': array([0.59081578, 0.91471203, 0.87900019, 1.30285398, 1.17073496,
#         1.27428699, 0.92973614, 1.34729973, 0.47572565, 1.02094754,
#         1.23994025, 0.59426332, 1.04056636, 1.30041575, 0.46240648,
#         1.49897933, 0.76119502, 1.40344675, 0.64731574, 0.98873695,
#         0.87060483, 0.57913605, 0.68499772, 1.4397529 , 0.88485678,
#         0.63648685, 0.88824526, 0.46821745, 0.74953667, 0.84690595,
#         1.38296525, 0.62428776, 0.52584473, 0.82820574, 1.63602829,
#         0.86941099, 1.4375364 , 0.72700524, 0.81691893, 0.84636585,
#         0.87173796, 1.48588069, 1.42827614, 0.78694328, 0.98937194,
#         0.75933862, 1.1967899 , 1.39827196, 1.26059413, 0.74499075,
#         0.46102858, 1.21255732, 0.72881103, 0.57049306, 1.07528583,
#         0.65019282, 1.61017028, 0.92094858, 0.64469425, 0.58661397,
#         0.86789727, 1.67363127, 1.3083694 , 1.00053906, 0.69092202,
#         0.70013801, 1.29556584, 1.26684586, 1.06151239, 1.28691117,
#         0.92088675, 0.4606878 , 0.83780376, 1.20249136, 1.41542951,
#         0.92583895, 0.89236649, 0.58635473, 0.86617271, 0.48617736,
#         0.625501  , 1.45736361, 0.61619902, 0.57606999, 0.72539576,
#         0.90831931, 0.59096265, 0.63539592, 0.63976367, 0.76847776,
#         1.49414674, 0.44359469, 0.4656237 , 1.04309138, 0.81800977,
#         1.44552581, 0.97183259, 1.57442331, 0.48450764, 0.8777744 ,
#         1.07878637, 1.14154545, 0.60980662, 1.06132642, 0.50529083,
#         0.65833855, 0.44824004, 0.77431337, 1.41717275, 0.52925674,
#         1.29537861, 1.32015904, 1.5190258 , 1.43562039, 0.87562148,
#         0.62119039, 0.47357988, 1.17233801, 0.70804238, 0.76107685,
#         0.46849577, 0.6307327 , 0.58351866, 0.82304597, 0.58871627,
#         0.61826332, 0.6178213 , 1.37521609, 1.10364286, 0.60273377,
#         1.11707624, 1.32108434, 0.82946404, 0.71436445, 0.43995492,
#         0.83137814, 0.77966213, 0.59912165, 0.43237607, 1.12056963,
#         1.24951347, 1.16465028, 0.74342895, 1.64954766, 1.3351206 ,
 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 0.01, 1,
#                     0.1, 0.1, 0.1, 100, 0.1, 0.1, 1, 0.1, 1e-05, 1, 0.01,
#                     0.01, 0.01, 1e-05, 1, 0.1, 0.01, 0.01, 1e-05, 0.01,
#                     0.1, 0.01, 1, 1, 100, 1, 1, 0.01, 0.01, 1e-05, 0.1, 1,
#                     100, 1, 0.1, 1e-05, 0.1, 0.1, 1, 100, 1, 0.01, 0.01,
#                     0.01, 100, 100, 0.1, 0.1, 1, 1, 0.1, 100, 1, 1e-05,
#                     1e-05, 1e-05, 0.01, 100, 0.01, 100, 0.01, 0.01, 100,
#                     0.01, 1, 0.01, 0.01, 0.01, 1, 100, 0.01, 0.01, 1e-05,
#                     100, 1, 1e-05, 1e-05, 1e-05, 1, 0.1, 0.01, 0.01, 1,
#                     1e-05, 1e-05, 1e-05, 1e-05, 100, 1, 1, 1e-05, 100, 0.1,
#                     1, 1e-05, 0.01, 1e-05, 1e-05, 0.01, 1e-05, 0.1, 1e-05,
#                     0.01, 100, 1e-05, 1e-05, 0.1, 100, 0.1, 1, 0.01, 1e-05,
#                     0.01, 0.01, 100, 1, 0.01, 0.1, 0.1, 100, 0.01, 0.01,
#                     100, 0.1, 100, 0.01, 0.01, 1e-05, 0.01, 0.1, 100, 0.1,
#                     1e-05, 100, 0.01, 1, 1, 0.1, 0.1, 100, 0.01, 0.1, 1,
#                     1e-05, 100, 100, 0.01, 1e-05, 1e-05, 100, 0.01, 1e-05,
#                     0.01],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_weight': masked_array(data=[3, 1, 3, 1, 1, 3, 3, 5, 5, 1, 5, 5, 5, 1, 5, 1, 3, 5,
#                     1, 3, 3, 5, 1, 3, 3, 3, 5, 3, 5, 1, 3, 1, 5, 5, 1, 5,
#                     3, 5, 3, 1, 5, 1, 3, 3, 3, 5, 5, 3, 1, 3, 1, 1, 1, 1,
#                     1, 1, 3, 3, 3, 1, 5, 3, 1, 1, 5, 3, 3, 5, 1, 5, 3, 1,
#                     1, 5, 1, 1, 1, 3, 5, 3, 3, 5, 5, 5, 1, 3, 5, 5, 3, 1,
#                     5, 3, 3, 5, 5, 5, 3, 1, 3, 3, 5, 5, 1, 1, 5, 1, 1, 5,
#                     3, 3, 3, 3, 1, 3, 3, 1, 3, 5, 1, 5, 3, 5, 5, 3, 5, 3,
#                     1, 3, 5, 3, 3, 5, 1, 1, 1, 1, 1, 3, 3, 3, 5, 3, 1, 1,
#                     3, 1, 5, 3, 5, 3, 1, 5, 3, 5, 5, 1, 5, 5, 3, 5, 1, 3,
#                     5, 1, 1, 3, 3, 1, 5, 3, 3, 5, 3, 5, 1, 1, 5, 5, 1, 3,
#                     3, 1, 5, 1, 5, 5, 3, 5, 1, 5, 5, 5, 1, 1, 5, 5, 1, 1,
#                     3, 5],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[10, 6, 6, 10, 8, 10, 6, 10, 6, 6, 10, 4, 6, 10, 8, 10,
#                     5, 10, 4, 6, 6, 4, 5, 10, 6, 4, 6, 8, 5, 6, 10, 4, 10,
#                     6, 10, 6, 10, 5, 6, 5, 6, 10, 10, 5, 6, 5, 8, 10, 8, 5,
#                     4, 8, 5, 4, 8, 4, 10, 6, 4, 4, 6, 10, 8, 6, 5, 5, 8,
#                     10, 8, 10, 6, 4, 6, 8, 10, 6, 5, 4, 6, 10, 4, 10, 4, 4,
#                     5, 5, 10, 4, 4, 5, 10, 5, 6, 8, 5, 10, 6, 10, 8, 6, 8,
#                     8, 4, 6, 4, 4, 5, 5, 10, 10, 10, 10, 10, 10, 6, 4, 8,
#                     8, 5, 4, 8, 4, 4, 6, 4, 4, 4, 10, 6, 4, 8, 8, 6, 5, 5,
#                     5, 5, 4, 4, 8, 8, 8, 5, 10, 10, 8, 5, 8, 10, 10, 8, 5,
#                     4, 8, 4, 10, 4, 4, 4, 4, 8, 6, 8, 10, 8, 4, 10, 5, 5,
#                     10, 8, 6, 5, 10, 8, 10, 6, 5, 10, 8, 5, 4, 10, 10, 10,
#                     6, 4, 8, 8, 10, 6, 6, 5, 6, 5, 6, 10, 8, 8, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=[0.3, 0.1, 0.2, 0.4, 0.1, 0.0, 0.4, 0.2, 0.4, 0.3, 0.2,
#                     0.1, 0.2, 0.4, 0.1, 0.4, 0.1, 0.2, 0.0, 0.0, 0.1, 0.3,
#                     0.4, 0.1, 0.3, 0.4, 0.4, 0.4, 0.3, 0.1, 0.4, 0.2, 0.0,
#                     0.3, 0.1, 0.0, 0.0, 0.2, 0.3, 0.4, 0.0, 0.2, 0.1, 0.1,
#                     0.4, 0.0, 0.0, 0.3, 0.2, 0.2, 0.4, 0.3, 0.3, 0.1, 0.1,
#                     0.0, 0.2, 0.0, 0.3, 0.4, 0.3, 0.3, 0.4, 0.2, 0.4, 0.2,
#                     0.2, 0.0, 0.3, 0.3, 0.1, 0.1, 0.0, 0.2, 0.0, 0.0, 0.4,
#                     0.2, 0.2, 0.1, 0.1, 0.3, 0.1, 0.4, 0.1, 0.0, 0.4, 0.4,
#                     0.4, 0.4, 0.1, 0.1, 0.2, 0.3, 0.0, 0.3, 0.4, 0.3, 0.2,
#                     0.0, 0.4, 0.4, 0.4, 0.3, 0.0, 0.0, 0.1, 0.2, 0.2, 0.1,
#                     0.4, 0.4, 0.4, 0.1, 0.1, 0.1, 0.1, 0.2, 0.0, 0.0, 0.4,
#                     0.4, 0.0, 0.4, 0.2, 0.3, 0.1, 0.2, 0.1, 0.0, 0.4, 0.3,
#                     0.3, 0.1, 0.2, 0.4, 0.0, 0.3, 0.1, 0.3, 0.1, 0.3, 0.4,
#                     0.1, 0.0, 0.3, 0.1, 0.4, 0.0, 0.0, 0.2, 0.0, 0.3, 0.3,
#                     0.2, 0.3, 0.1, 0.1, 0.3, 0.2, 0.4, 0.2, 0.4, 0.3, 0.0,
#                     0.2, 0.2, 0.1, 0.3, 0.4, 0.3, 0.4, 0.2, 0.0, 0.1, 0.2,
#                     0.2, 0.2, 0.0, 0.0, 0.0, 0.3, 0.4, 0.0, 0.4, 0.3, 0.4,
#                     0.3, 0.4, 0.0, 0.3, 0.4, 0.3, 0.3, 0.3, 0.0, 0.4, 0.4,
#                     0.0, 0.2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_colsample_bytree': masked_array(data=[0.6, 0.9, 0.7, 0.6, 0.9, 0.6, 0.8, 0.6, 0.7, 0.9, 0.7,
#                     0.7, 0.9, 0.6, 0.6, 0.9, 0.9, 0.9, 0.9, 0.7, 0.8, 0.6,
#                     0.6, 0.7, 0.9, 0.8, 0.9, 0.9, 0.8, 0.7, 0.6, 0.7, 0.9,
#                     0.7, 0.9, 0.8, 0.9, 0.7, 0.7, 0.8, 0.7, 0.9, 0.9, 0.9,
#                     0.9, 0.9, 0.7, 0.8, 0.8, 0.8, 0.8, 0.9, 0.7, 0.6, 0.6,
#                     0.9, 0.9, 0.9, 0.9, 0.6, 0.7, 0.9, 0.9, 0.6, 0.7, 0.6,
#                     0.8, 0.7, 0.6, 0.6, 0.9, 0.9, 0.7, 0.6, 0.8, 0.9, 0.8,
#                     0.6, 0.8, 0.7, 0.9, 0.9, 0.8, 0.6, 0.7, 0.8, 0.9, 0.9,
#                     0.8, 0.6, 0.9, 0.7, 0.9, 0.6, 0.8, 0.7, 0.6, 0.7, 0.6,
#                     0.8, 0.8, 0.9, 0.7, 0.9, 0.8, 0.9, 0.7, 0.9, 0.7, 0.8,
#                     0.6, 0.7, 0.7, 0.9, 0.7, 0.7, 0.7, 0.9, 0.6, 0.8, 0.8,
#                     0.9, 0.6, 0.6, 0.6, 0.8, 0.7, 0.7, 0.9, 0.7, 0.8, 0.9,
#                     0.6, 0.6, 0.6, 0.6, 0.8, 0.6, 0.6, 0.8, 0.8, 0.9, 0.7,
#                     0.9, 0.6, 0.8, 0.9, 0.7, 0.7, 0.8, 0.8, 0.6, 0.7, 0.9,
#                     0.6, 0.9, 0.8, 0.9, 0.6, 0.7, 0.6, 0.6, 0.9, 0.6, 0.7,
#                     0.9, 0.7, 0.6, 0.8, 0.8, 0.6, 0.6, 0.8, 0.6, 0.8, 0.7,
#                     0.9, 0.7, 0.6, 0.6, 0.9, 0.6, 0.6, 0.9, 0.8, 0.9, 0.9,
#                     0.9, 0.9, 0.8, 0.8, 0.6, 0.7, 0.6, 0.7, 0.6, 0.9, 0.7,
#                     0.8, 0.7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'subsample': 0.8,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.0,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 100,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.1,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.1,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 8,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.3,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 100,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.0,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 0.1,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.2,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 0.1,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.2,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.8,
#    'reg_alpha': 100,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.1,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 4,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 8,
#    'gamma': 0.2,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.0,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 100,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 3,
#    'max_depth': 4,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.2,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 100,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 5,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 0.1,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 0.1,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 8,
#    'gamma': 0.2,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.4,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 100,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.0,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.6,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.7,
#    'reg_alpha': 1,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 10,
#    'gamma': 0.1,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 3,
#    'max_depth': 6,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.9,
#    'reg_alpha': 1,
#    'min_child_weight': 1,
#    'max_depth': 4,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 3,
#    'max_depth': 8,
#    'gamma': 0.1,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 8,
#    'gamma': 0.2,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.0,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.8,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 4,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
# ...
#    'gamma': 0.4,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 1,
#    'max_depth': 5,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 6,
#    'gamma': 0.3,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.9,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 5,
#    'gamma': 0.3,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.6,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 5,
#    'max_depth': 6,
#    'gamma': 0.0,
#    'colsample_bytree': 0.6},
#   {'subsample': 0.6,
#    'reg_alpha': 100,
#    'min_child_weight': 1,
#    'max_depth': 10,
#    'gamma': 0.4,
#    'colsample_bytree': 0.9},
#   {'subsample': 0.9,
#    'reg_alpha': 0.01,
#    'min_child_weight': 1,
#    'max_depth': 8,
#    'gamma': 0.4,
#    'colsample_bytree': 0.7},
#   {'subsample': 0.7,
#    'reg_alpha': 1e-05,
#    'min_child_weight': 3,
#    'max_depth': 8,
#    'gamma': 0.0,
#    'colsample_bytree': 0.8},
#   {'subsample': 0.8,
#    'reg_alpha': 0.01,
#    'min_child_weight': 5,
#    'max_depth': 10,
#    'gamma': 0.2,
#    'colsample_bytree': 0.7}],
#  'split0_test_score': array([0.88421794, 0.8907938 , 0.89267262, 0.88609676, 0.88750587,
#         0.88727102, 0.89235948, 0.89040238, 0.87865978, 0.8927509 ,
#         0.88695788, 0.89478628, 0.88938469, 0.88578362, 0.88077345,
#         0.88186942, 0.89259433, 0.88664475, 0.89408173, 0.89439486,
#         0.89384688, 0.89509942, 0.8942383 , 0.88625333, 0.89118522,
#         0.89549084, 0.89267262, 0.88085173, 0.89290747, 0.89095037,
#         0.88813214, 0.894708  , 0.88437451, 0.89392516, 0.8795209 ,
#         0.89282918, 0.88327853, 0.89541256, 0.8922812 , 0.8942383 ,
#         0.89181149, 0.88006889, 0.88484421, 0.8927509 , 0.89157664,
#         0.89267262, 0.89102865, 0.88594019, 0.88594019, 0.8927509 ,
#         0.87936433, 0.88453108, 0.89376859, 0.89541256, 0.88828871,
#         0.89361202, 0.88429623, 0.89142007, 0.8942383 , 0.89556912,
#         0.89298575, 0.88633161, 0.88695788, 0.89345546, 0.89455143,
#         0.8951777 , 0.89040238, 0.88656646, 0.88797558, 0.8893064 ,
#         0.8922812 , 0.87576327, 0.89188978, 0.89181149, 0.88351339,
#         0.89110694, 0.894708  , 0.89502114, 0.89353374, 0.88335682,
#         0.89596054, 0.88672303, 0.89447315, 0.89478628, 0.89298575,
#         0.89439486, 0.88453108, 0.8942383 , 0.89533427, 0.89455143,
#         0.88586191, 0.87638954, 0.87654611, 0.89048066, 0.89384688,
#         0.89008924, 0.89447315, 0.88280883, 0.8810083 , 0.89345546,
#         0.89008924, 0.88954126, 0.89603883, 0.89087208, 0.88085173,
#         0.89361202, 0.87638954, 0.89329889, 0.88601848, 0.88507907,
#         0.88727102, 0.88875842, 0.88249569, 0.88601848, 0.89181149,
#         0.89603883, 0.88046031, 0.88844528, 0.89392516, 0.89369031,
#         0.88132143, 0.89580398, 0.89549084, 0.89361202, 0.89376859,
#         0.89603883, 0.89635196, 0.88711445, 0.89212463, 0.89455143,
#         0.88875842, 0.8907938 , 0.89212463, 0.89392516, 0.87529357,
#         0.89502114, 0.89478628, 0.89502114, 0.87881635, 0.8864099 ,
#         0.8893064 , 0.89071552, 0.89400344, 0.87944262, 0.88703617,
#         0.88742759, 0.89431658, 0.88914984, 0.88570534, 0.88547049,
#         0.0006487 , 0.00246564, 0.00207842, 0.00192642, 0.00178171,
#         0.00176559, 0.00097008, 0.00140184, 0.00123282, 0.00148854,
#         0.00143923, 0.00131202, 0.00150492, 0.00125634, 0.00078545,
#         0.0015622 , 0.00094158, 0.00221082, 0.00207809, 0.00147614,
#         0.00101535, 0.00243758, 0.00084556, 0.00201758, 0.00175553,
#         0.0007992 , 0.0011941 , 0.0012805 , 0.00049648, 0.00096515,
#         0.00150311, 0.00039055, 0.00163086, 0.00242807, 0.0019008 ,
#         0.00131046, 0.00132596, 0.00113684, 0.00158685, 0.00167941,
#         0.00182402, 0.00057645, 0.00163212, 0.00100456, 0.00191472]),
#  'rank_test_score': array([167,  95,  67, 154, 139, 138,  83, 102, 192,  76, 133,  20, 104,
#         149, 176, 174,  65, 148,  24,  53,  57,  10,  59, 145,  89,  38,
#          72, 186,  48,  73, 134,   4, 164,  66, 185,  61, 171,  57,  87,
#          56,  90, 180, 152,  64,  84,  69, 105, 136, 143,  71, 191, 151,
#          41,   1, 110,  27, 157,  78,  35,  14,  74, 144, 137,  55,  47,
#          30, 109, 130, 132, 106,  88, 193,  80,  85, 167,  92,  30,  25,
#          61, 173,  36, 146,  34,  15,  28,  44, 156,  25,   2,  43, 149,
#         197, 195,  98,  51, 100,  54, 161, 178,  60, 116, 106,  16,  93,
#         181,  33, 197,  61, 139, 159, 120, 124, 160, 146,  86,   5, 179,
#         114,  49,  45, 177,  23,  13,  51,  37,   7,   2, 139,  81,  12,
#         116,  96,  79,  38, 199,  10,  41,  28, 189, 120, 103, 111,  45,
#         184, 130, 126,  20, 111, 129, 155, 169,  50,  17, 126, 190, 163,
#          17,  32,   8,   6, 122, 187, 108, 158, 113,  17, 172,  22,  82,
#         170,  97, 188,  68, 128, 114, 166,  74, 183, 162, 119, 194,   9,
#         101, 175, 123,  91, 200, 139, 153, 135,  93, 182, 196,  70,  40,
#          76, 165,  98, 116, 125], dtype=int32)}

# %%
best_params = tuning_xgb_rcv.best_params_
best_params
# Out:
# {'subsample': 0.8,
#  'reg_alpha': 1,
#  'min_child_weight': 1,
#  'max_depth': 4,
#  'gamma': 0.1,
#  'colsample_bytree': 0.6}

# %%
tuning_xgb_rcv.best_score_
# Out:
# 0.8953342727415062

# %%
tune_clf = tuning_xgb_rcv.best_estimator_
tune_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
tuning_score = tune_clf.score(X_test, y_test)
tuning_score
# Out:
# 0.8999025815879201

# %%
tune_pred = tune_clf.predict(X_test)
cm = confusion_matrix(tune_pred, y_test)
cm
# Out:
# array([[7831, 1208],
#        [ 436, 6949]])

# %%
plt.figure(figsize=(14,10))
sns.heatmap(cm, annot=True,cmap='Blues', fmt='g')
# Out:
# <AxesSubplot:>

# %%
tp, fn, fp, tn = confusion_matrix(y_test, tune_pred).reshape(-1)
print('This is True Positive: ', tp)
print('This is True Negetive: ', tn)
print('This is False Positive: ', fp)
print('This is False Negetive: ', fn)
# Out:
# This is True Positive:  7831
# This is True Negetive:  6949
# This is False Positive:  1208
# This is False Negetive:  436
